# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('Gastos y costos 20-23.xlsx')
df
# Out:
#      CALOR Y CONTROL S.A DE C.V Unnamed: 1  \
# 0              DEDUCCIONES 2020        NaN
# 1                           NaN        NaN
# 2                           NaN        NaN
# 3                           NaN        NaN
# 4                         FECHA      FOLIO
# ...                         ...        ...
# 3342        2020-12-01 00:00:00     125834
# 3343        2020-12-01 00:00:00      37652
# 3344        2020-12-01 00:00:00        160
# 3345        2020-12-01 00:00:00     634875
# 3346        2020-12-01 00:00:00    1044477
#
#                                 Unnamed: 2    Unnamed: 3  \
# 0                                      NaN           NaN
# 1                                      NaN           NaN
# 2                                      NaN           NaN
# 3                                      NaN           NaN
# 4                                     UUID           RFC
# ...                                    ...           ...
# ...

# %%
df = df.drop(range(0,4))
df.columns = df.iloc[0]
df = df[1:]
df
# Out:
# 4                   FECHA                   FOLIO  \
# 5     2020-01-01 00:00:00                   39408
# 6     2020-01-01 00:00:00  0001010100750847116902
# 7     2020-01-01 00:00:00  0001010100752163714102
# 8     2020-01-01 00:00:00                    3663
# 9     2020-01-01 00:00:00                    2849
# ...                   ...                     ...
# 3342  2020-12-01 00:00:00                  125834
# 3343  2020-12-01 00:00:00                   37652
# 3344  2020-12-01 00:00:00                     160
# 3345  2020-12-01 00:00:00                  634875
# 3346  2020-12-01 00:00:00                 1044477
#
# 4                                     UUID           RFC  \
# 5     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 6     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 7     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 8     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# 9     EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3  ENA7006081P0
# ...

# %%
#Convertir Dataframe a CSV
df.to_csv('SincolumnastNA.csv')

# %%
df.isnull().sum()
# Out:
# 4
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %%
df['GASTO'].mode()
# Out:
# 0    COMPRA
# Name: GASTO, dtype: object

# %%
df['GASTO'] = df['GASTO'].fillna('COMPRA')

# %%
#Convertir Dataframe a CSV
df.to_csv('GastoNA.csv')

# %%
df['TC'] = df['TC'].fillna(1)

# %%
#Convertir Dataframe a CSV
df.to_csv('TCNA.csv')

# %%
df['IMPORTE'] = df['IMPORTE'].fillna(df['IMPORTE'].median())

# %%
#Convertir Dataframe a CSV
df.to_csv('IMPORTENa.csv')

# %%
df['IVA'] = df['IVA'].fillna(df['IVA'].mean())

# %%
#Convertir Dataframe a CSV
df.to_csv('IVANA.csv')

# %%
df['TIPO'] = df['TIPO'].fillna('I')

# %%
#Convertir Dataframe a CSV
df.to_csv('TIPONA.csv')

# %%
df['POLIZA'] = df['POLIZA'].replace('NO LOS METI', 'PE07-ENE20')
df['POLIZA'] = df['POLIZA'].fillna('PE07-ENE20')

# %%
#Convertir Dataframe a CSV
df.to_csv('POLIZANA.csv')

# %%
df.isnull().sum()
# Out:
# 4
# FECHA            0
# FOLIO          189
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# GASTO            0
# DESCRIPCION      0
# TC               0
# IMPORTE          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# POLIZA           0
# Columna1         0
# dtype: int64

# %%
df['POLIZA'].value_counts()
# Out:
# PE07-ENE20    3325
# PE03-ENE20       1
# PE51-ENE20       1
# PE54-ENE20       1
# PE53-ENE20       1
# PE50-ENE20       1
# PE48-ENE20       1
# PE46-ENE20       1
# PE39-ENE20       1
# PE36-ENE20       1
# PE4ENE20         1
# PE31-ENE20       1
# PE09-ENE20       1
# PE02-ENE20       1
# PE06-ENE20       1
# PE05-ENE20       1
# PE04-ENE20       1
# PE49-ENE20       1
# Name: POLIZA, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 5 to 3346
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3342 non-null   object
#  1   FOLIO        3153 non-null   object
#  2   UUID         3342 non-null   object
#  3   RFC          3342 non-null   object
#  4   PROVEEDOR    3342 non-null   object
#  5   TIPO GASTO   3342 non-null   object
#  6   GASTO        3342 non-null   object
#  7   DESCRIPCION  3342 non-null   object
#  8   TC           3342 non-null   float64
#  9   IMPORTE      3342 non-null   float64
#  10  IVA          3342 non-null   float64
#  11  RET ISR      3342 non-null   object
#  12  RET IVA      3342 non-null   object
#  13  TOTAL MX     3342 non-null   object
#  14  TOTAL SAT    3342 non-null   object
#  15  TIPO         3342 non-null   object
#  16  STATUS       3342 non-null   object
#  17  POLIZA       3342 non-null   object
# ...

# %%
df = df.drop('FOLIO', axis = 1)

# %%
#Convertir Dataframe a CSV
df.to_csv('SinFOLIO.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 5 to 3346
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3342 non-null   object
#  1   UUID         3342 non-null   object
#  2   RFC          3342 non-null   object
#  3   PROVEEDOR    3342 non-null   object
#  4   TIPO GASTO   3342 non-null   object
#  5   GASTO        3342 non-null   object
#  6   DESCRIPCION  3342 non-null   object
#  7   TC           3342 non-null   float64
#  8   IMPORTE      3342 non-null   float64
#  9   IVA          3342 non-null   float64
#  10  RET ISR      3342 non-null   object
#  11  RET IVA      3342 non-null   object
#  12  TOTAL MX     3342 non-null   object
#  13  TOTAL SAT    3342 non-null   object
#  14  TIPO         3342 non-null   object
#  15  STATUS       3342 non-null   object
#  16  POLIZA       3342 non-null   object
#  17  Columna1     3342 non-null   object
# ...

# %% [markdown]
# Convertimos algunas variables que son strings a flotantes para poder trabajar con dichos datos.

# %%
df['RET ISR'] = df['RET ISR'].astype('float')
df['RET IVA'] = df['RET IVA'].astype('float')
df['TOTAL MX'] = df['TOTAL MX'].astype('float')
df['TOTAL SAT'] = df['TOTAL SAT'].astype('float')

# %%
df.dtypes
# Out:
# 4
# FECHA           object
# UUID            object
# RFC             object
# PROVEEDOR       object
# TIPO GASTO      object
# GASTO           object
# DESCRIPCION     object
# TC             float64
# IMPORTE        float64
# IVA            float64
# RET ISR        float64
# RET IVA        float64
# TOTAL MX       float64
# TOTAL SAT      float64
# TIPO            object
# STATUS          object
# POLIZA          object
# Columna1        object
# dtype: object

# %%
fig = plt.figure(figsize = (15, 8))
df.plot(kind='box', vert = False)
plt.title('Valores Atípicos del DataFrame')
plt.show()

# %% [markdown]
# Creamos un nuevo dataframe con algunas de las variables del dataframe pasado para sacar los valores atipicos, y poder eliminar outliers con metodos de desviacion estandar y rango intercuartilico.

# %%
df1 = df[['TC', 'IMPORTE', 'IVA', 'RET ISR', 'RET IVA', 'TOTAL MX', 'TOTAL SAT']]
df1
# Out:
# 4      TC   IMPORTE          IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 5     1.0      0.00  2248.280000      0.0      0.0   2248.28   16300.00
# 6     1.0    490.00    78.400000      0.0      0.0    568.40     568.40
# 7     1.0    195.00    31.200000      0.0      0.0    226.20     226.20
# 8     1.0  10694.25  1711.080000      0.0      0.0  12405.33   12405.33
# 9     1.0      0.00   519.824801      0.0      0.0      0.00       0.00
# ...   ...       ...          ...      ...      ...       ...        ...
# 3342  1.0    129.79    20.210000      0.0      0.0    150.00     150.00
# 3343  1.0   2284.80   365.570000      0.0      0.0   2650.37    2650.37
# 3344  1.0    163.79    26.210000      0.0      0.0    190.00     190.00
# 3345  1.0      0.00     0.000000      0.0      0.0      0.00       0.00
# 3346  1.0  14889.29     0.000000      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 7 columns]

# %% [markdown]
# Desviacion estandar para eliminar outliers en DataFrame nuevo.

# %%
y= df1
Limite_Superior= y.mean() + 3 * y.std()
Limite_Inferior= y.mean() - 3 * y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 4
# TC               4.239688
# IMPORTE      25155.492600
# IVA           4563.167626
# RET ISR        667.271992
# RET IVA        958.239955
# TOTAL MX     28488.002843
# TOTAL SAT    33250.398514
# dtype: float64
# Limite inferior permitido 4
# TC              -2.129870
# IMPORTE     -18910.907561
# IVA          -3523.518023
# RET ISR       -627.750813
# RET IVA       -839.215179
# TOTAL MX    -21455.655297
# TOTAL SAT   -25762.462834
# dtype: float64

# %%
df2 = df1[(y<=Limite_Superior)&(y>=Limite_Inferior)]
df2
# Out:
# 4      TC   IMPORTE          IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 5     1.0      0.00  2248.280000      0.0      0.0   2248.28   16300.00
# 6     1.0    490.00    78.400000      0.0      0.0    568.40     568.40
# 7     1.0    195.00    31.200000      0.0      0.0    226.20     226.20
# 8     1.0  10694.25  1711.080000      0.0      0.0  12405.33   12405.33
# 9     1.0      0.00   519.824801      0.0      0.0      0.00       0.00
# ...   ...       ...          ...      ...      ...       ...        ...
# 3342  1.0    129.79    20.210000      0.0      0.0    150.00     150.00
# 3343  1.0   2284.80   365.570000      0.0      0.0   2650.37    2650.37
# 3344  1.0    163.79    26.210000      0.0      0.0    190.00     190.00
# 3345  1.0      0.00     0.000000      0.0      0.0      0.00       0.00
# 3346  1.0  14889.29     0.000000      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 7 columns]

# %%
valores_nulos = df1.isnull().sum()
valores_nulos
# Out:
# 4
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
df_limpio=df2.copy()
df_limpio=df_limpio.fillna(round(df2.mean(),1))
df_limpio
# Out:
# 4      TC   IMPORTE          IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 5     1.0      0.00  2248.280000      0.0      0.0   2248.28   16300.00
# 6     1.0    490.00    78.400000      0.0      0.0    568.40     568.40
# 7     1.0    195.00    31.200000      0.0      0.0    226.20     226.20
# 8     1.0  10694.25  1711.080000      0.0      0.0  12405.33   12405.33
# 9     1.0      0.00   519.824801      0.0      0.0      0.00       0.00
# ...   ...       ...          ...      ...      ...       ...        ...
# 3342  1.0    129.79    20.210000      0.0      0.0    150.00     150.00
# 3343  1.0   2284.80   365.570000      0.0      0.0   2650.37    2650.37
# 3344  1.0    163.79    26.210000      0.0      0.0    190.00     190.00
# 3345  1.0      0.00     0.000000      0.0      0.0      0.00       0.00
# 3346  1.0  14889.29     0.000000      0.0      0.0  14889.29   14889.29
#
# [3342 rows x 7 columns]

# %%
valores_nulos=df_limpio.isnull().sum()
valores_nulos
# Out:
# 4
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
fig = plt.figure(figsize = (15, 8))
df_limpio.plot(kind='box', vert = False)
plt.title('Valores Atípicos del DataFrame')
plt.show()

# %%
df_limpio.to_csv("DF 2020 1, Desviacion estandar.csv")

# %% [markdown]
# Rango intercuartilico para eliminar outliers en DataFrame nuevo.

# %%
y=df1

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 4
# TC              1.000000
# IMPORTE      6929.045000
# IVA          1280.695753
# RET ISR         0.000000
# RET IVA         0.000000
# TOTAL MX     7983.177500
# TOTAL SAT    8269.283750
# dtype: float64
# Limite inferior permitido 4
# TC              1.000000
# IMPORTE     -4127.075000
# IVA          -748.293452
# RET ISR         0.000000
# RET IVA         0.000000
# TOTAL MX    -4783.142500
# TOTAL SAT   -4832.966250
# dtype: float64

# %%
df3_iqr= df1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
df3_iqr
# Out:
# 4      TC  IMPORTE         IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 5     1.0     0.00         NaN      0.0      0.0   2248.28        NaN
# 6     1.0   490.00   78.400000      0.0      0.0    568.40     568.40
# 7     1.0   195.00   31.200000      0.0      0.0    226.20     226.20
# 8     1.0      NaN         NaN      0.0      0.0       NaN        NaN
# 9     1.0     0.00  519.824801      0.0      0.0      0.00       0.00
# ...   ...      ...         ...      ...      ...       ...        ...
# 3342  1.0   129.79   20.210000      0.0      0.0    150.00     150.00
# 3343  1.0  2284.80  365.570000      0.0      0.0   2650.37    2650.37
# 3344  1.0   163.79   26.210000      0.0      0.0    190.00     190.00
# 3345  1.0     0.00    0.000000      0.0      0.0      0.00       0.00
# 3346  1.0      NaN    0.000000      0.0      0.0       NaN        NaN
#
# [3342 rows x 7 columns]

# %%
valores_nulos=df3_iqr.isnull().sum()
valores_nulos
# Out:
# 4
# TC             9
# IMPORTE      424
# IVA          347
# RET ISR       45
# RET IVA      253
# TOTAL MX     420
# TOTAL SAT    426
# dtype: int64

# %%
df5_iqr=df3_iqr.copy()
df5_iqr=df5_iqr.fillna(round(df3_iqr.mean(),1))
df5_iqr
# Out:
# 4      TC  IMPORTE         IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 5     1.0     0.00  222.200000      0.0      0.0   2248.28    1333.00
# 6     1.0   490.00   78.400000      0.0      0.0    568.40     568.40
# 7     1.0   195.00   31.200000      0.0      0.0    226.20     226.20
# 8     1.0  1082.00  222.200000      0.0      0.0   1239.10    1333.00
# 9     1.0     0.00  519.824801      0.0      0.0      0.00       0.00
# ...   ...      ...         ...      ...      ...       ...        ...
# 3342  1.0   129.79   20.210000      0.0      0.0    150.00     150.00
# 3343  1.0  2284.80  365.570000      0.0      0.0   2650.37    2650.37
# 3344  1.0   163.79   26.210000      0.0      0.0    190.00     190.00
# 3345  1.0     0.00    0.000000      0.0      0.0      0.00       0.00
# 3346  1.0  1082.00    0.000000      0.0      0.0   1239.10    1333.00
#
# [3342 rows x 7 columns]

# %%
fig = plt.figure(figsize = (15, 8))
df5_iqr.plot(kind='box', vert = False)
plt.title('Valores Atípicos del DataFrame')
plt.show()

# %%
df5_iqr.to_csv("DF 2020 2, Cuartiles.csv")
